# %%
import numpy as np
import pandas as pd
from scipy.integrate import solve_ivp
from lmfit import minimize, Parameters, Parameter, report_fit
import matplotlib.pyplot as plt; plt.rc('font', size=16)
import matplotlib.cm as cm
import gLV_diet

cols = [cm.tab10(i) for i in range(10)]
cols.append(cm.Set2(5))
cols.append(cm.Paired(4))

# %% [markdown]
# # Test de la implementación del algoritmo de ajuste por mínimos cuadrados

# %%
species=range(3)
x0=np.ones(len(species))*10
t_span=[0, 42]
t_span = [0, 42]
t_eval = np.linspace(t_span[0], t_span[-1], 1000)

test1 = gLV_diet.TestData(species, x0, t_span, t_eval)
test1.params
test1.dynamics_simulation()
test1.noisy_data()
test1.fit_gLV()
test1.plot_dynamics()
plt.show()
test1.plot_trajectories(x_log=False)
plt.show()

# %%
species=range(6)
x0=np.ones(len(species))*10
t_span=[0, 42]
t_span = [0, 42]
t_eval = np.linspace(t_span[0], t_span[-1], 1000)

test1 = gLV_diet.TestData(species, x0, t_span, t_eval)
test1.params
test1.dynamics_simulation()
test1.noisy_data()
test1.fit_gLV()
test1.plot_dynamics()
plt.show()
test1.plot_trajectories(x_log=False)
plt.show()

# %% [markdown]
# ***
# # Ajuste a mis datos

# %%
data = pd.read_pickle('COPROseq_absolute_abundance.pkl')
data
# Out:
#                        Strain Treatment  Day  Absolute_abundance
# 0                   B. caccae       LF0    1        5.151164e+07
# 1     B. cellulosilyticus WH2       LF0    1        7.110996e+07
# 2                   B. ovatus       LF0    1        8.427954e+07
# 3         B. thetaiotaomicron       LF0    1        3.218013e+07
# 4                B. uniformis       LF0    1        7.739366e+06
# ...                       ...       ...  ...                 ...
# 4495              C. scindens       HF0   42        4.633884e+07
# 4496            C. spiroforme       HF0   42        8.481661e+05
# 4497           D. longicatena       HF0   42        3.302648e+04
# 4498            P. distasonis       HF0   42        3.108796e+07
# 4499                 R. obeum       HF0   42        2.518618e+07
#
# [4500 rows x 4 columns]

# %%
LF0 = gLV_diet.Experiment(data, treatment='LF0')
HF0 = gLV_diet.Experiment(data, treatment='HF0')

# %%
report_fit(LF0.fit_gLV())
# Out:
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 169
#     # data points      = 2100
#     # variables        = 168
#     chi-square         = 2.1244e+39
#     reduced chi-square = 1.0996e+36
#     Akaike info crit   = 174435.700
#     Bayesian info crit = 175384.848
# ##  Warning: uncertainties could not be estimated:
#     growth_1:           at initial value
#     susceptibility_1:   at initial value
#     cross_int_1_1:      at initial value
#     cross_int_1_2:      at initial value
#     cross_int_1_3:      at initial value
#     cross_int_1_4:      at initial value
#     cross_int_1_5:      at initial value
#     cross_int_1_6:      at initial value
#     cross_int_1_7:      at initial value
#     cross_int_1_8:      at initial value
#     cross_int_1_9:      at initial value
#     cross_int_1_10:     at initial value
#     cross_int_1_11:     at initial value
#     cross_int_1_12:     at initial value
#     growth_2:           at initial value
#     susceptibility_2:   at initial value
#     cross_int_2_1:      at initial value
#     cross_int_2_2:      at initial value
#     cross_int_2_3:      at initial value
#     cross_int_2_4:      at initial value
#     cross_int_2_5:      at initial value
#     cross_int_2_6:      at initial value
#     cross_int_2_7:      at initial value
#     cross_int_2_8:      at initial value
#     cross_int_2_9:      at initial value
#     cross_int_2_10:     at initial value
#     cross_int_2_11:     at initial value
#     cross_int_2_12:     at initial value
#     growth_3:           at initial value
#     susceptibility_3:   at initial value
#     cross_int_3_1:      at initial value
#     cross_int_3_2:      at initial value
#     cross_int_3_3:      at initial value
#     cross_int_3_4:      at initial value
#     cross_int_3_5:      at initial value
#     cross_int_3_6:      at initial value
#     cross_int_3_7:      at initial value
#     cross_int_3_8:      at initial value
#     cross_int_3_9:      at initial value
#     cross_int_3_10:     at initial value
#     cross_int_3_11:     at initial value
#     cross_int_3_12:     at initial value
#     growth_4:           at initial value
#     susceptibility_4:   at initial value
#     cross_int_4_1:      at initial value
#     cross_int_4_2:      at initial value
#     cross_int_4_3:      at initial value
#     cross_int_4_4:      at initial value
#     cross_int_4_5:      at initial value
#     cross_int_4_6:      at initial value
#     cross_int_4_7:      at initial value
#     cross_int_4_8:      at initial value
#     cross_int_4_9:      at initial value
#     cross_int_4_10:     at initial value
#     cross_int_4_11:     at initial value
#     cross_int_4_12:     at initial value
#     growth_5:           at initial value
#     susceptibility_5:   at initial value
#     cross_int_5_1:      at initial value
#     cross_int_5_2:      at initial value
#     cross_int_5_3:      at initial value
#     cross_int_5_4:      at initial value
#     cross_int_5_5:      at initial value
#     cross_int_5_6:      at initial value
#     cross_int_5_7:      at initial value
#     cross_int_5_8:      at initial value
#     cross_int_5_9:      at initial value
#     cross_int_5_10:     at initial value
#     cross_int_5_11:     at initial value
#     cross_int_5_12:     at initial value
#     growth_6:           at initial value
#     susceptibility_6:   at initial value
#     cross_int_6_1:      at initial value
#     cross_int_6_2:      at initial value
#     cross_int_6_3:      at initial value
#     cross_int_6_4:      at initial value
#     cross_int_6_5:      at initial value
#     cross_int_6_6:      at initial value
#     cross_int_6_7:      at initial value
#     cross_int_6_8:      at initial value
#     cross_int_6_9:      at initial value
#     cross_int_6_10:     at initial value
#     cross_int_6_11:     at initial value
#     cross_int_6_12:     at initial value
#     growth_7:           at initial value
#     susceptibility_7:   at initial value
#     cross_int_7_1:      at initial value
#     cross_int_7_2:      at initial value
#     cross_int_7_3:      at initial value
#     cross_int_7_4:      at initial value
#     cross_int_7_5:      at initial value
#     cross_int_7_6:      at initial value
#     cross_int_7_7:      at initial value
#     cross_int_7_8:      at initial value
#     cross_int_7_9:      at initial value
#     cross_int_7_10:     at initial value
#     cross_int_7_11:     at initial value
#     cross_int_7_12:     at initial value
#     growth_8:           at initial value
#     susceptibility_8:   at initial value
#     cross_int_8_1:      at initial value
#     cross_int_8_2:      at initial value
#     cross_int_8_3:      at initial value
#     cross_int_8_4:      at initial value
#     cross_int_8_5:      at initial value
#     cross_int_8_6:      at initial value
#     cross_int_8_7:      at initial value
#     cross_int_8_8:      at initial value
#     cross_int_8_9:      at initial value
#     cross_int_8_10:     at initial value
#     cross_int_8_11:     at initial value
#     cross_int_8_12:     at initial value
#     growth_9:           at initial value
#     susceptibility_9:   at initial value
#     cross_int_9_1:      at initial value
#     cross_int_9_2:      at initial value
#     cross_int_9_3:      at initial value
#     cross_int_9_4:      at initial value
#     cross_int_9_5:      at initial value
#     cross_int_9_6:      at initial value
#     cross_int_9_7:      at initial value
#     cross_int_9_8:      at initial value
#     cross_int_9_9:      at initial value
#     cross_int_9_10:     at initial value
#     cross_int_9_11:     at initial value
#     cross_int_9_12:     at initial value
#     growth_10:          at initial value
#     susceptibility_10:  at initial value
#     cross_int_10_1:     at initial value
#     cross_int_10_2:     at initial value
#     cross_int_10_3:     at initial value
#     cross_int_10_4:     at initial value
#     cross_int_10_5:     at initial value
#     cross_int_10_6:     at initial value
#     cross_int_10_7:     at initial value
#     cross_int_10_8:     at initial value
#     cross_int_10_9:     at initial value
#     cross_int_10_10:    at initial value
#     cross_int_10_11:    at initial value
#     cross_int_10_12:    at initial value
#     growth_11:          at initial value
#     susceptibility_11:  at initial value
#     cross_int_11_1:     at initial value
#     cross_int_11_2:     at initial value
#     cross_int_11_3:     at initial value
#     cross_int_11_4:     at initial value
#     cross_int_11_5:     at initial value
#     cross_int_11_6:     at initial value
#     cross_int_11_7:     at initial value
#     cross_int_11_8:     at initial value
#     cross_int_11_9:     at initial value
#     cross_int_11_10:    at initial value
#     cross_int_11_11:    at initial value
#     cross_int_11_12:    at initial value
#     growth_12:          at initial value
#     susceptibility_12:  at initial value
#     cross_int_12_1:     at initial value
#     cross_int_12_2:     at initial value
#     cross_int_12_3:     at initial value
#     cross_int_12_4:     at initial value
#     cross_int_12_5:     at initial value
#     cross_int_12_6:     at initial value
#     cross_int_12_7:     at initial value
#     cross_int_12_8:     at initial value
#     cross_int_12_9:     at initial value
#     cross_int_12_10:    at initial value
#     cross_int_12_11:    at initial value
#     cross_int_12_12:    at initial value
# [[Variables]]
#     species:            12 (fixed)
#     growth_1:           3.35979182 (init = 3.359792)
#     susceptibility_1:   4.22547487 (init = 4.225475)
#     cross_int_1_1:     -1.27963722 (init = -1.279637)
#     cross_int_1_2:      1.91281087 (init = 1.912811)
#     cross_int_1_3:     -1.83541186 (init = -1.835412)
#     cross_int_1_4:     -0.98803895 (init = -0.9880389)
#     cross_int_1_5:      1.15166063 (init = 1.151661)
#     cross_int_1_6:     -0.21825870 (init = -0.2182587)
#     cross_int_1_7:     -1.31236615 (init = -1.312366)
#     cross_int_1_8:     -0.97672783 (init = -0.9767278)
#     cross_int_1_9:     -1.15117769 (init = -1.151178)
#     cross_int_1_10:    -1.37044223 (init = -1.370442)
#     cross_int_1_11:     1.37313827 (init = 1.373138)
#     cross_int_1_12:    -0.39199463 (init = -0.3919946)
#     growth_2:           4.17864987 (init = 4.17865)
#     susceptibility_2:  -2.84694836 (init = -2.846948)
#     cross_int_2_1:      1.76112690 (init = 1.761127)
#     cross_int_2_2:     -0.06101619 (init = -0.06101619)
#     cross_int_2_3:      1.65679450 (init = 1.656794)
#     cross_int_2_4:     -0.56645338 (init = -0.5664534)
#     cross_int_2_5:     -0.31808037 (init = -0.3180804)
#     cross_int_2_6:      0.58578172 (init = 0.5857817)
#     cross_int_2_7:     -0.52234936 (init = -0.5223494)
#     cross_int_2_8:      0.26318722 (init = 0.2631872)
#     cross_int_2_9:     -1.61552163 (init = -1.615522)
#     cross_int_2_10:     1.40541979 (init = 1.40542)
#     cross_int_2_11:    -1.69691446 (init = -1.696914)
#     cross_int_2_12:    -1.52788815 (init = -1.527888)
#     growth_3:           4.53166482 (init = 4.531665)
#     susceptibility_3:  -0.08135013 (init = -0.08135013)
#     cross_int_3_1:      0.68273886 (init = 0.6827389)
#     cross_int_3_2:      1.83553055 (init = 1.835531)
#     cross_int_3_3:     -3.12356582 (init = -3.123566)
#     cross_int_3_4:      1.49773883 (init = 1.497739)
#     cross_int_3_5:     -0.51108010 (init = -0.5110801)
#     cross_int_3_6:      1.59535413 (init = 1.595354)
#     cross_int_3_7:     -0.90245477 (init = -0.9024548)
#     cross_int_3_8:     -0.63055694 (init = -0.6305569)
#     cross_int_3_9:      1.65062768 (init = 1.650628)
#     cross_int_3_10:    -1.23188871 (init = -1.231889)
#     cross_int_3_11:     0.08959748 (init = 0.08959748)
#     cross_int_3_12:     1.59983059 (init = 1.599831)
#     growth_4:           7.78741089 (init = 7.787411)
#     susceptibility_4:  -3.06979119 (init = -3.069791)
#     cross_int_4_1:     -1.25962735 (init = -1.259627)
#     cross_int_4_2:      1.97629835 (init = 1.976298)
#     cross_int_4_3:     -0.24713868 (init = -0.2471387)
#     cross_int_4_4:     -3.29955237 (init = -3.299552)
#     cross_int_4_5:     -1.89480340 (init = -1.894803)
#     cross_int_4_6:     -0.64632549 (init = -0.6463255)
#     cross_int_4_7:      0.96028903 (init = 0.960289)
#     cross_int_4_8:      1.03074348 (init = 1.030743)
#     cross_int_4_9:     -1.25901642 (init = -1.259016)
#     cross_int_4_10:     0.35513556 (init = 0.3551356)
#     cross_int_4_11:     1.11378406 (init = 1.113784)
#     cross_int_4_12:    -1.04183995 (init = -1.04184)
#     growth_5:           6.66007832 (init = 6.660078)
#     susceptibility_5:  -1.53510984 (init = -1.53511)
#     cross_int_5_1:      1.95608467 (init = 1.956085)
#     cross_int_5_2:      1.43192582 (init = 1.431926)
#     cross_int_5_3:      0.73015532 (init = 0.7301553)
#     cross_int_5_4:      1.07660869 (init = 1.076609)
#     cross_int_5_5:     -3.60025409 (init = -3.600254)
#     cross_int_5_6:     -1.96720439 (init = -1.967204)
#     cross_int_5_7:     -1.38599785 (init = -1.385998)
#     cross_int_5_8:      1.93741919 (init = 1.937419)
#     cross_int_5_9:      1.75837447 (init = 1.758374)
#     cross_int_5_10:    -0.14446082 (init = -0.1444608)
#     cross_int_5_11:    -0.51512235 (init = -0.5151223)
#     cross_int_5_12:     1.10684658 (init = 1.106847)
#     growth_6:           4.19900088 (init = 4.199001)
#     susceptibility_6:  -4.58172343 (init = -4.581723)
#     cross_int_6_1:     -1.35161431 (init = -1.351614)
#     cross_int_6_2:      0.76580493 (init = 0.7658049)
#     cross_int_6_3:      0.12392685 (init = 0.1239269)
#     cross_int_6_4:     -1.74576330 (init = -1.745763)
#     cross_int_6_5:     -0.91178700 (init = -0.911787)
#     cross_int_6_6:     -1.29156151 (init = -1.291562)
#     cross_int_6_7:      0.68037689 (init = 0.6803769)
#     cross_int_6_8:     -0.10297668 (init = -0.1029767)
#     cross_int_6_9:      0.43543794 (init = 0.4354379)
#     cross_int_6_10:     1.00664603 (init = 1.006646)
#     cross_int_6_11:     1.98238497 (init = 1.982385)
#     cross_int_6_12:    -1.20512099 (init = -1.205121)
#     growth_7:           0.66931526 (init = 0.6693153)
#     susceptibility_7:  -4.44071082 (init = -4.440711)
#     cross_int_7_1:     -1.68970371 (init = -1.689704)
#     cross_int_7_2:     -1.18522222 (init = -1.185222)
#     cross_int_7_3:      0.54316188 (init = 0.5431619)
#     cross_int_7_4:     -1.09272114 (init = -1.092721)
#     cross_int_7_5:     -0.03209062 (init = -0.03209062)
#     cross_int_7_6:      0.40587232 (init = 0.4058723)
#     cross_int_7_7:     -1.46145603 (init = -1.461456)
#     cross_int_7_8:     -1.27167121 (init = -1.271671)
#     cross_int_7_9:      1.68963292 (init = 1.689633)
#     cross_int_7_10:    -1.86264013 (init = -1.86264)
#     cross_int_7_11:     1.20011698 (init = 1.200117)
#     cross_int_7_12:     0.72007762 (init = 0.7200776)
#     growth_8:           3.28875455 (init = 3.288755)
#     susceptibility_8:  -0.87501187 (init = -0.8750119)
#     cross_int_8_1:      1.00705858 (init = 1.007059)
#     cross_int_8_2:      0.81927096 (init = 0.819271)
#     cross_int_8_3:     -1.39697554 (init = -1.396976)
#     cross_int_8_4:     -0.50300924 (init = -0.5030092)
#     cross_int_8_5:      0.83407332 (init = 0.8340733)
#     cross_int_8_6:     -0.97313361 (init = -0.9731336)
#     cross_int_8_7:     -0.51647127 (init = -0.5164713)
#     cross_int_8_8:     -3.70129637 (init = -3.701296)
#     cross_int_8_9:     -1.15037160 (init = -1.150372)
#     cross_int_8_10:    -1.88418930 (init = -1.884189)
#     cross_int_8_11:    -1.37470124 (init = -1.374701)
#     cross_int_8_12:    -0.50885100 (init = -0.508851)
#     growth_9:           7.23558797 (init = 7.235588)
#     susceptibility_9:  -4.28490367 (init = -4.284904)
#     cross_int_9_1:     -1.31708050 (init = -1.31708)
#     cross_int_9_2:      1.35948693 (init = 1.359487)
#     cross_int_9_3:      0.31681036 (init = 0.3168104)
#     cross_int_9_4:     -0.09492819 (init = -0.09492819)
#     cross_int_9_5:      0.04601230 (init = 0.0460123)
#     cross_int_9_6:     -1.29746563 (init = -1.297466)
#     cross_int_9_7:     -1.18227090 (init = -1.182271)
#     cross_int_9_8:      1.61380982 (init = 1.61381)
#     cross_int_9_9:     -4.79111970 (init = -4.79112)
#     cross_int_9_10:     0.71137008 (init = 0.7113701)
#     cross_int_9_11:    -1.54534293 (init = -1.545343)
#     cross_int_9_12:     0.99535768 (init = 0.9953577)
#     growth_10:          7.30386291 (init = 7.303863)
#     susceptibility_10: -3.51894504 (init = -3.518945)
#     cross_int_10_1:    -1.39051191 (init = -1.390512)
#     cross_int_10_2:    -1.59268067 (init = -1.592681)
#     cross_int_10_3:    -1.40248861 (init = -1.402489)
#     cross_int_10_4:    -0.72293406 (init = -0.7229341)
#     cross_int_10_5:     0.49212360 (init = 0.4921236)
#     cross_int_10_6:    -0.84181087 (init = -0.8418109)
#     cross_int_10_7:    -0.63612630 (init = -0.6361263)
#     cross_int_10_8:     1.68091907 (init = 1.680919)
#     cross_int_10_9:    -0.46331011 (init = -0.4633101)
#     cross_int_10_10:   -0.06985333 (init = -0.06985333)
#     cross_int_10_11:   -0.70289681 (init = -0.7028968)
#     cross_int_10_12:   -0.69904719 (init = -0.6990472)
#     growth_11:          7.41869571 (init = 7.418696)
#     susceptibility_11:  3.53292429 (init = 3.532924)
#     cross_int_11_1:     0.71279288 (init = 0.7127929)
#     cross_int_11_2:    -0.70014163 (init = -0.7001416)
#     cross_int_11_3:     0.23432466 (init = 0.2343247)
#     cross_int_11_4:     1.76968965 (init = 1.76969)
#     cross_int_11_5:    -0.62979408 (init = -0.6297941)
#     cross_int_11_6:    -1.45418163 (init = -1.454182)
#     cross_int_11_7:    -0.81320876 (init = -0.8132088)
#     cross_int_11_8:    -0.81713250 (init = -0.8171325)
#     cross_int_11_9:     1.71952250 (init = 1.719522)
#     cross_int_11_10:    1.65308518 (init = 1.653085)
#     cross_int_11_11:   -3.48201617 (init = -3.482016)
#     cross_int_11_12:   -0.40939208 (init = -0.4093921)
#     growth_12:          5.12083516 (init = 5.120835)
#     susceptibility_12:  3.42160071 (init = 3.421601)
#     cross_int_12_1:    -1.91522990 (init = -1.91523)
#     cross_int_12_2:     1.94539785 (init = 1.945398)
#     cross_int_12_3:     0.89261162 (init = 0.8926116)
#     cross_int_12_4:     0.41277082 (init = 0.4127708)
#     cross_int_12_5:    -0.09003600 (init = -0.090036)
#     cross_int_12_6:    -0.01622907 (init = -0.01622907)
#     cross_int_12_7:     0.64275188 (init = 0.6427519)
#     cross_int_12_8:    -1.63242270 (init = -1.632423)
#     cross_int_12_9:     1.72095372 (init = 1.720954)
#     cross_int_12_10:    0.97426493 (init = 0.9742649)
#     cross_int_12_11:   -0.00609686 (init = -0.006096864)
#     cross_int_12_12:   -0.07137163 (init = -0.07137163)
